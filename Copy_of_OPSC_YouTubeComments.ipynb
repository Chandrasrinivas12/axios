# %% [markdown]
# <a href="https://colab.research.google.com/github/Chandrasrinivas12/axios/blob/main/Copy_of_OPSC_YouTubeComments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pull Comments

# %%
import googleapiclient.discovery
import googleapiclient.errors

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyBTUXFdz4dlYlexmqo6f5dCeEUl2FbXv30"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="UP1tWImU_b8",
    maxResults=100
)
response = request.execute()

for item in response['items']:
    print(item['snippet']['topLevelComment']['snippet']['textDisplay'])
# Out:
# Excellent camera work!
# Love story in vit? 😂😂myth
# Apart from the presentation,  the message is also good. Though not so crisp and clear but atleast a signal has been made what not to do
# Unbelievably shooting camera like
# 19-23 batch senior here, don&#39;t take this video as motivation to not care about CGPA at all. It is crucial to balance both things appropriately, during your first two years give more important to CGPA and during your last 2 give importance to practical skills (DSA, projects and internships if you&#39;re in a CSE-related branch). Source: 9 pointer with super dream offer
# Director hari made a wonderful job. Kudos to his dedication
# the theme is actually well reflected pls acquire as many skills as possible u are not required to get 9.8 cgpa get atleast 8 cgpa but acquire as many skills
# Chaala baagundhi bayya
# amazing transitions and  background music Awesome🥳🥳
# ...

# %% [markdown]
# ## Output as Pandas DataFrame

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyBTUXFdz4dlYlexmqo6f5dCeEUl2FbXv30"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="UP1tWImU_b8",
    maxResults=100
)
response = request.execute()

comments = []

for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        comment['textDisplay']
    ])

df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text'])

df.head(10)
# Out:
#                       author          published_at            updated_at  \
# 0  @aishwaryasreenivasan6660  2023-08-25T04:19:38Z  2023-08-25T04:19:38Z
# 1            @adityarana3722  2023-07-05T05:55:30Z  2023-07-05T05:55:30Z
# 2         @PrinceKumar-hh6yn  2023-06-22T21:01:44Z  2023-06-22T21:01:44Z
# 3         @PrinceKumar-hh6yn  2023-06-22T20:47:08Z  2023-06-22T20:47:08Z
# 4                @night23412  2023-06-20T08:31:24Z  2023-06-20T08:31:24Z
# 5             @syamreddy1764  2023-06-07T10:13:26Z  2023-06-07T10:13:26Z
# 6              @sujoysen9405  2023-05-24T13:55:41Z  2023-05-24T13:55:41Z
# 7           @bhanuprasadhere  2023-05-18T21:18:01Z  2023-05-18T21:18:01Z
# 8         @gladwindaniel6064  2023-05-16T16:38:45Z  2023-05-16T16:38:45Z
# 9              @hanutsai6427  2023-05-11T05:44:16Z  2023-05-11T05:44:16Z
#
#    like_count                                               text
# 0           0                             Excellent camera work!
# ...

# %%
df.head()
